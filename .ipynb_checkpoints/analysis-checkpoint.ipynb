# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('./clean_data.csv')
df.drop_duplicates(subset=['country'],inplace=True)
df = df.set_index('country')
df.head()
# Out:
#                     total_cases new_cases  total_deaths  new_deaths  \
# country
# United States           1686436       NaN       99300.0         NaN
# Brazil                   365213   #ERROR!       22746.0        30.0
# Russian Federation       344481       NaN        3541.0         NaN
# Spain                    282852       NaN       28752.0         NaN
# United Kingdom           259559       NaN       36793.0         NaN
#
#                     total_recovered  active_cases  critical_cases  \
# country
# United States              451702.0     1135434.0         17135.0
# Brazil                     149911.0      192556.0          8318.0
# Russian Federation         113299.0      227641.0          2300.0
# Spain                      196958.0       57142.0           854.0
# United Kingdom                  NaN           NaN          1559.0
#
#                     cases_per_million  deaths_per_million  total_tests  \
# country
# United States                  5098.0               300.0   14749756.0
# Brazil                         1719.0               107.0     735224.0
# Russian Federation             2361.0                24.0    8685305.0
# Spain                          6050.0               615.0    3556567.0
# United Kingdom                 3825.0               542.0    3458905.0
#
#                     tests_per_million  population  obesity  median_age  \
# country
# United States                 44587.0   330806424     36.2        41.0
# Brazil                         3461.0   212405664     22.1        32.6
# Russian Federation            59518.0   145928315     23.1        39.6
# Spain                         76071.0    46752999     23.8        42.7
# United Kingdom                50979.0    67850075     27.8        40.5
#
#                     median_age_male  median_age_female  gdp_per_capita  \
# country
# United States                  39.9               41.9         67426.0
# Brazil                         31.1               32.8         17106.0
# Russian Federation             36.6               42.5         30820.0
# Spain                          41.5               43.9         43007.0
# United Kingdom                 39.3               41.7         48169.0
#
#                     avg_temp_c
# country
# United States             8.55
# Brazil                   24.95
# Russian Federation       -5.10
# Spain                    13.30
# United Kingdom            8.45

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
np.fill_diagonal(corr.values, 0)
corr.sort_values(by='deaths_per_million')
# Out:
#                     total_cases  total_deaths  new_deaths  total_recovered  \
# avg_temp_c            -0.176036     -0.175435   -0.039011        -0.215881
# population             0.253314      0.196821    0.477154         0.316417
# deaths_per_million     0.251855      0.397892    0.428673         0.296880
# critical_cases         0.888431      0.797045   -0.038555         0.809679
# active_cases           0.981096      0.907596    0.027705         0.843815
# obesity                0.209383      0.203041    0.503857         0.220588
# total_tests            0.918496      0.832713    0.025910         0.893129
# total_cases            0.000000      0.937337    0.145141         0.931154
# total_recovered        0.931154      0.913408    0.269703         0.000000
# tests_per_million      0.074639      0.099610   -0.152769         0.096208
# gdp_per_capita         0.205790      0.205913    0.783614         0.232434
# median_age_female      0.165097      0.197659    0.096195         0.216546
# median_age             0.168862      0.201995    0.079232         0.222284
# total_deaths           0.937337      0.000000    0.284872         0.913408
# median_age_male        0.167832      0.203163    0.065505         0.223104
# new_deaths             0.145141      0.284872    0.000000         0.269703
# cases_per_million      0.187027      0.220400    0.153606         0.203819
#
#                     active_cases  critical_cases  cases_per_million  \
# avg_temp_c             -0.134374       -0.053067          -0.232381
# population              0.211394        0.429433          -0.054859
# deaths_per_million      0.173633        0.130301           0.721245
# critical_cases          0.884673        0.000000           0.110099
# active_cases            0.000000        0.884673           0.155372
# obesity                 0.181252        0.106784           0.357121
# total_tests             0.886650        0.775348           0.194672
# total_cases             0.981096        0.888431           0.187027
# total_recovered         0.843815        0.809679           0.203819
# tests_per_million       0.050804       -0.012010           0.564761
# gdp_per_capita          0.169621        0.072245           0.643732
# median_age_female       0.114552        0.056521           0.329985
# median_age              0.117229        0.061334           0.370159
# total_deaths            0.907596        0.797045           0.220400
# median_age_male         0.115213        0.058685           0.391801
# new_deaths              0.027705       -0.038555           0.153606
# cases_per_million       0.155372        0.110099           0.000000
#
#                     deaths_per_million  total_tests  tests_per_million  \
# avg_temp_c                   -0.311753    -0.260409          -0.330481
# population                   -0.025927     0.364644          -0.102564
# deaths_per_million            0.000000     0.240940           0.344083
# critical_cases                0.130301     0.775348          -0.012010
# active_cases                  0.173633     0.886650           0.050804
# obesity                       0.207643     0.209235           0.365525
# total_tests                   0.240940     0.000000           0.140846
# total_cases                   0.251855     0.918496           0.074639
# total_recovered               0.296880     0.893129           0.096208
# tests_per_million             0.344083     0.140846           0.000000
# gdp_per_capita                0.356350     0.229842           0.657306
# median_age_female             0.377674     0.218643           0.429693
# median_age                    0.388818     0.220937           0.464228
# total_deaths                  0.397892     0.832713           0.099610
# median_age_male               0.398989     0.217604           0.481693
# new_deaths                    0.428673     0.025910          -0.152769
# cases_per_million             0.721245     0.194672           0.564761
#
#                     population   obesity  median_age  median_age_male  \
# avg_temp_c           -0.034461 -0.287262   -0.638231        -0.617502
# population            0.000000 -0.181767    0.005649         0.004042
# deaths_per_million   -0.025927  0.207643    0.388818         0.398989
# critical_cases        0.429433  0.106784    0.061334         0.058685
# active_cases          0.211394  0.181252    0.117229         0.115213
# obesity              -0.181767  0.000000    0.487631         0.504833
# total_tests           0.364644  0.209235    0.220937         0.217604
# total_cases           0.253314  0.209383    0.168862         0.167832
# total_recovered       0.316417  0.220588    0.222284         0.223104
# tests_per_million    -0.102564  0.365525    0.464228         0.481693
# gdp_per_capita       -0.051933  0.458766    0.640063         0.671487
# median_age_female     0.005908  0.458211    0.995232         0.984772
# median_age            0.005649  0.487631    0.000000         0.996666
# total_deaths          0.196821  0.203041    0.201995         0.203163
# median_age_male       0.004042  0.504833    0.996666         0.000000
# new_deaths            0.477154  0.503857    0.079232         0.065505
# cases_per_million    -0.054859  0.357121    0.370159         0.391801
#
#                     median_age_female  gdp_per_capita  avg_temp_c
# avg_temp_c                  -0.659266       -0.327752    0.000000
# population                   0.005908       -0.051933   -0.034461
# deaths_per_million           0.377674        0.356350   -0.311753
# critical_cases               0.056521        0.072245   -0.053067
# active_cases                 0.114552        0.169621   -0.134374
# obesity                      0.458211        0.458766   -0.287262
# total_tests                  0.218643        0.229842   -0.260409
# total_cases                  0.165097        0.205790   -0.176036
# total_recovered              0.216546        0.232434   -0.215881
# tests_per_million            0.429693        0.657306   -0.330481
# gdp_per_capita               0.588389        0.000000   -0.327752
# median_age_female            0.000000        0.588389   -0.659266
# median_age                   0.995232        0.640063   -0.638231
# total_deaths                 0.197659        0.205913   -0.175435
# median_age_male              0.984772        0.671487   -0.617502
# new_deaths                   0.096195        0.783614   -0.039011
# cases_per_million            0.329985        0.643732   -0.232381

# %% [markdown]
# ## Hypothesis
#
# * Temperature doesnt kill COVID. Poorer countries happen to have higher average temperature and they also have lower median age and obesity.
# * Tests per million vs new deaths: Better testing and healthcare means less deaths? or. Countries which can afford to have better testing have lower population so they are already nearning the end of the wave?

# %%
ddf = df.apply(pd.to_numeric, errors='coerce')
ddf = ddf.apply(lambda x: (x - x.mean())/x.std(), axis=0)
ddf.fillna(0, inplace=True)
# ddf.dropna(how='any',inplace=True)
ddf
# Out:
#                        total_cases  new_cases  total_deaths  new_deaths  \
# country
# United States            13.083189        0.0     10.796084    0.000000
# Brazil                    2.670895        0.0      2.304589   -0.076873
# Russian Federation        2.507510        0.0      0.174339    0.000000
# Spain                     2.021824        0.0      2.970784    0.000000
# United Kingdom            1.838257        0.0      3.862705    0.000000
# ...                            ...        ...           ...         ...
# Caribbean Netherlands    -0.207229        0.0      0.000000    0.000000
# St. Barth                -0.207229        0.0      0.000000    0.000000
# Anguilla                 -0.207252        0.0      0.000000    0.000000
# Lesotho                  -0.207260        0.0      0.000000    0.000000
# Saint Pierre Miquelon    -0.207268        0.0      0.000000    0.000000
#
#                        total_recovered  active_cases  critical_cases  \
# country
# United States                10.621955     13.695239        8.874963
# Brazil                        3.344504      2.195888        4.192866
# Russian Federation            2.461634      2.623785        0.997124
# Spain                         4.479005      0.544378        0.229254
# United Kingdom                0.000000      0.000000        0.603630
# ...                                ...           ...             ...
# Caribbean Netherlands        -0.270337     -0.152527        0.000000
# St. Barth                    -0.270337     -0.152527        0.000000
# Anguilla                     -0.270409     -0.152527        0.000000
# Lesotho                       0.000000     -0.152502        0.000000
# Saint Pierre Miquelon        -0.270457     -0.152527        0.000000
#
#                        cases_per_million  deaths_per_million  total_tests  \
# country
# United States                   1.593211            1.557054    10.455978
# Brazil                          0.204063            0.301909     0.252500
# Russian Federation              0.467997           -0.237869     6.040669
# Spain                           1.984590            3.605607     2.306618
# United Kingdom                  1.069865            3.130863     2.235514
# ...                                  ...                 ...          ...
# Caribbean Netherlands          -0.408494            0.000000    -0.282482
# St. Barth                      -0.252683            0.000000    -0.282691
# Anguilla                       -0.420416            0.000000    -0.282769
# Lesotho                        -0.502269            0.000000    -0.282585
# Saint Pierre Miquelon          -0.431516            0.000000     0.000000
#
#                        tests_per_million  population   obesity  median_age  \
# country
# United States                   0.517003    2.058219  2.009989    1.123748
# Brazil                         -0.576041    1.228954  0.421160    0.190017
# Russian Federation              0.913837    0.763355  0.533843    0.968126
# Spain                           1.353782    0.068743  0.612721    1.312717
# United Kingdom                  0.686889    0.216504  1.063453    1.068168
# ...                                  ...         ...       ...         ...
# Caribbean Netherlands          -0.237890   -0.258526  0.000000    0.000000
# St. Barth                      -0.299258   -0.258641  0.000000    0.000000
# Anguilla                       -0.614844   -0.258605  0.000000    0.434565
# Lesotho                        -0.664518   -0.243718 -0.198595   -0.743714
# Saint Pierre Miquelon           0.000000   -0.258669  0.000000    0.000000
#
#                        median_age_male  median_age_female  gdp_per_capita  \
# country
# United States                 1.140276           1.087783        1.806201
# Brazil                        0.115150           0.126976       -0.292462
# Russian Federation            0.755854           1.151133        0.279499
# Spain                         1.326662           1.298950        0.787774
# United Kingdom                1.070381           1.066667        1.003062
# ...                                ...                ...             ...
# Caribbean Netherlands         0.000000           0.000000        0.000000
# St. Barth                     0.000000           0.000000        0.000000
# Anguilla                      0.324835           0.538751        0.000000
# Lesotho                      -0.688642          -0.781039       -0.853453
# Saint Pierre Miquelon         0.000000           0.000000        0.000000
#
#                        avg_temp_c
# country
# United States           -1.162222
# Brazil                   0.793379
# Russian Federation      -2.789902
# Spain                   -0.595813
# United Kingdom          -1.174146
# ...                           ...
# Caribbean Netherlands    0.000000
# St. Barth                0.000000
# Anguilla                 0.000000
# Lesotho                 -0.768717
# Saint Pierre Miquelon    0.000000
#
# [209 rows x 18 columns]

# %%
y = ddf['deaths_per_million'].values
keys = list(set(ddf.keys()) - set(['deaths_per_million','median_age']))
x = ddf[keys].values

# %%
reg = LinearRegression().fit(x, y)
reg.score(x, y)
# Out:
# 0.6607972212817825

# %%
weights = pd.DataFrame({'weight':reg.coef_, 'name':keys})
sns.barplot(x="weight", y="name", data=weights)

# %%
y = ddf['deaths_per_million'].values
keys = ['obesity', 'gdp_per_capita','avg_temp_c','median_age_male','median_age_female','population','tests_per_million']
x = ddf[keys].values

# %%
reg = LinearRegression().fit(x, y)
reg.score(x, y)
# Out:
# 0.18735923536315147

# %%
weights = pd.DataFrame({'weight':reg.coef_, 'name':keys})
sns.barplot(x="weight", y="name", data=weights)

# %%
x.shape
# Out:
# (209, 7)

# %%
df['cases_per_test'] = df['total_cases']/df['total_tests']
df.sort_values(by=['cases_per_test'], inplace=True, ascending=False,)
df['cases_per_test'].head()
# Out:
# country
# Sudan                    9.526185
# Yemen                    1.850000
# Sao Tome and Principe    1.434286
# Equatorial Guinea        1.124122
# Guinea-Bissau            0.742667
# Name: cases_per_test, dtype: float64

# %%
sdf = df.head(25)
sns.barplot(x="cases_per_test", y=sdf.index, data=sdf)

# %%
df['cases_per_test_per_million'] = df['cases_per_million']/df['tests_per_million']
df.sort_values(by=['cases_per_test_per_million'], inplace=True, ascending=False,)
df['cases_per_test_per_million'].head()
# Out:
# country
# Sudan                    9.666667
# Yemen                    1.750000
# Sao Tome and Principe    1.435000
# Equatorial Guinea        1.124386
# Guinea-Bissau            0.743455
# Name: cases_per_test_per_million, dtype: float64

# %%
sdf = df.head(25)
sns.barplot(x="cases_per_test_per_million", y=sdf.index, data=sdf)
